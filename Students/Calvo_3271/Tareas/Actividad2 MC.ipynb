# %% [markdown]
# # Actividad 02: Librerias y modelamiento básico
#
# ### Profesor: Juan Marcos Marín Ramírez
# #### Métodos Computacionales
# ---

# %% [markdown]
# ## 1.
# Una persona conduce una moto con rapidez constante $v_m$, mientras que un policia lo hace con aceleración constante $a_p$ (iniciando desde el reposo). Suponga que ambos movimientos inician en $t=0$, haga una gráfica para el movimiento de la moto y del policia, donde el usuario ingrese la velocidad (moto) y aceleración (policia). Además determine el instante $t$ en el cual se encuentran ambos. Ambos movimientos iniciarán en $x_i = 0$
#
# **Pruebe**: para $v_m$ = 15m/s y $a_p$ = 3 m/s², el tiempo deberia ser 10 s
#
#
# $$x_f = x_i + v_m\cdot t$$
#
# $$x_f = x_i + v_o\cdot t + \frac{1}{2}a_p\cdot t^2$$

# %%
import numpy as np
import matplotlib.pyplot as plt
vmoto=float(input("Velocidad de la moto"))
atombo=float(input("Aceleración del policía"))
tinter=2*(vmoto/atombo)  #Se despeja el timepo al igualar las ecuaciones cinemáticas
t=np.linspace(0,2*tinter)  #para asegurarme de que el punto de intersección esté en la gráfica sin importar los datos del input, el dominio va hasta 2tinter
xmoto=vmoto*t
xtombo=(1/2)*atombo*(t**2)
plt.plot(t,xtombo, color="b", linestyle="--", label=f"Policía, uniformemente acelerado a {atombo}$m/s^2$")
plt.plot(t,xmoto, color= "g", label=f"Moto, a velocidad constante de {vmoto}m/s")
plt.scatter(tinter, vmoto*tinter, color="r", label=f"Punto de intersección, t={tinter}")
plt.legend()

# %% [markdown]
# 3}33---
#
# ##2.
# El potencial Lennard-Jones es un modelo simple que aproxima la interacción entre un par de moléculas neutras. Este está definido como:
#
# $$
# V(r) = 4\epsilon \left[ \left( \frac{\sigma}{r} \right)^{12} - \left( \frac{\sigma}{r} \right)^{6} \right]
# $$
#
# Donde:
# - $V(r)$ es el potencial en función de la distancia interatómica $r$.
# - $\epsilon$ es la profundidad del pozo de potencial, es decir, la energía mínima que describe la interacción entre dos partículas.
# - $\sigma$ es la distancia a la cual el potencial es cero, también conocido como el parámetro de distancia.
# - $r$ es la distancia entre las dos partículas.
#
# a. Escriba una función para encontrar modelar el potencial LJ.
#
#
# b. Usando $\sigma = \epsilon = 1$ demuestre que la distancia de equilibrio $r_m$ es aproximadamente $r_m = 2^{1/6}\sigma$. Para esto realice un gráfico del potencial, especificando los ejes. Trunque la serie en $r_c = 2.5\sigma$.
#
#
# c. Verifique que $r_m = 2^{1/6}\sigma$ se cumple para diferentes valores de $\sigma$, dejando $\epsilon$ constante.

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
def V(epsilon,sigma,r):
  rx=np.linspace(sigma,2.5*sigma)
  V= 4*epsilon*((sigma/rx)**12-(sigma/rx)**6)
  plt.xlabel("Distancia entre partículas")
  plt.ylabel("Potencial")
  plt.plot(rx,V, color="orange")
  plt.axvline(sigma*(2**(1/6)), color="b", linestyle="--", label= f"$r_m$ 2^1/6 $\cdot$ {sigma} ≈ {round(sigma*(2**(1/6)),2)}")
  plt.axhline(min(V), color="r",linestyle="-.", label= f" V({round(sigma*(2**(1/6)),2)}) = {round(min(V),2)}")
  plt.legend()
  plt.show()
  return 4*epsilon*((sigma/r)**12-(sigma/r)**6)

print(V(1,1,1),
      V(1,random.randint(1,100),random.randint(1,100))) #Aquí hay un entero aleatorio entre 0 y 100 para sigma y para r, solo para mostrar que se sigue cumpliendo para valores distintos de sigma

# %% [markdown]
# ##3.
# El siguiente código exporta tablas html de sitios web
#
# ```python
# import pandas as pd
#
# # Dataset 1
# # URL of the webpage
# url = "https://worldpopulationreview.com/country-rankings/average-height-by-country"
#
# # Read the HTML content
# html_content = pd.read_html(url)
#
# alturas = html_content[0]
#
# # Dataset 2
# # URL of the webpage
# url = "https://worldpopulationreview.com/country-rankings/average-net-worth-by-country"
#
# # Read the HTML content
# html_content = pd.read_html(url)
#
# income = html_content[0]
# ````
#
# El primer dataset muestra las alturas medias de niñ@s de 19 años.
#
# a. Limpie los datos, eliminando columnas en *(in)* y cambie todos los nombres de las columnas al español.
#
# b. Realice un gráfico de barras, donde se muestre una comparación de la estatura media para niños (cm) y niñas (cm) en ambas categorias. Esto para los primeros 10 paises con mayor y menor altura, además agregue a Colombia.
#
# c. ¿Existirá una relación entre la riqueza y la altura? Usando el dataset `income`, haga un merge con el dataset `alturas`. Ahora, empleando los datos de altura para los 10 mayores (19 años) y 10 menores (19 años). Realice un gráfico donde relacione la altura media con el GDP y concluya si existe alguna relación.

# %%
import pandas as pd
import matplotlib.pyplot as plt
url1 = "https://worldpopulationreview.com/country-rankings/average-height-by-country"
contenido1 = pd.read_html(url1)
url2 = "https://worldpopulationreview.com/country-rankings/average-net-worth-by-country"
contenido2 = pd.read_html(url2)
alturas = contenido1[0]
ingresos = contenido2[0]
alturas.pop("Boys 19 (in)")
alturas.pop("Girls 19 (in)")
alturas.pop("Unnamed: 0")              #Borrar todo lo que no sirve para nada
ingresos.pop("Unnamed: 0")
ingresos.pop("Wealth per Adult 2022↓")
ingresos.pop("Total Wealth 2022")
ingresos.pop("Share of World Wealth 2022")
todo = pd.merge(alturas,ingresos)  #Junté de una vez los datos de alturas con los de gdp
todo = todo.rename(columns={'Country': 'País', 'Average Height, Boys, 19 yo (cm)↓': 'Altura promedio, hombres de 19 años (cm)', "Girls 19 (cm)":"Mujeres de 19 años (cm)","GDP per Adult 2022":"GDP por adulto (en miles)"}) #Cambiar títulos de columnas
todo=todo.sort_values(by='Altura promedio, hombres de 19 años (cm)')  #que quede ordenado respecto a las alturas de los hombres
ult10=todo.tail(10)
first10=todo.head(10)
Colombia = todo[todo['País'] == "Colombia"]    #Los últimos 10, los primeros 10 y Colombia
todo=todo.set_index('País', drop=True)  #Queda mejor si el propio índice son los paises y no los números
ostia=pd.concat([ult10,first10,Colombia])
ostia=ostia.sort_values(by= 'Altura promedio, hombres de 19 años (cm)', ascending=False)  #Acá los vuelvo a ordenar para que el dato de Colombia quede en el puesto en el que va
ostia = ostia.set_index('País', drop=True)
ostia['GDP por adulto (en miles)'] = ostia['GDP por adulto (en miles)'].str.replace('$', '', ).str.replace(',', '.')
ostia['GDP por adulto (en miles)'] = pd.to_numeric(ostia['GDP por adulto (en miles)'], errors='coerce')
ostia.plot(kind="bar")  #Gráfico de barras

ostia
